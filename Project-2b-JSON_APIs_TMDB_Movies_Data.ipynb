# %% [markdown]
# # Project: Data Import - Working with Web APIs and JSON (Movies Dataset)

# %% [markdown]
# ## About APIs

# %% [markdown]
# *Application programming interfaces* (APIs) are a way for one program to interact with another.
# API calls are the medium by which they interact.
# An API call, or API request, is a message sent to a server asking an API to provide a service or information.

# %% [markdown]
# There are four different types of APIs commonly used in web services: public, partner, private and composite.

# %% [markdown]
# APIs are used to integrate new applications with existing software systems.
# This increases development speed because each functionality doesn't have to be written from scratch.
# You can use APIs to leverage existing code.

# %% [markdown]
# ## About TMDB

# %% [markdown]
# The Movie Database (TMDB) is a popular, community-built database for movies and TV shows.
# All the content has been added and updated by users dating back to the year 2008.
# TMDB is a free, collaborative database about films.

# %% [markdown]
# ## OBJECTIVE

# %% [markdown]
# 1. In this project I am going to use free TMDB API for importing data about films.
# 2. Firstly I will import data of a movie whose movie id is 140607 for inspecting the structure of response.
# 3. Secondly I will import data of movies with the help of their movie id.
# 4. Keep the records into pandas dataframe and save them in json format(best practices).

# %% [markdown]
# ### Deliverable

# %% [markdown]
# Save the raw data of movies in a csv file (real world scenario).

# %% [markdown]
# ## Importing Libraries

# %%
import requests
import json
import pandas as pd
pd.options.display.max_columns = 30
# Out:
# C:\Users\palab\AppData\Roaming\Python\Python38\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %% [markdown]
# ## Working with APIs and JSON

# %%
api_key  = "api_key=1c571334abe41d484f25418c5c97ae3d"
movie_id = 140607
movie_api = "https://api.themoviedb.org/3/movie/{}?"
url = movie_api.format(movie_id) + api_key
url
# Out:
# 'https://api.themoviedb.org/3/movie/140607?api_key=1c571334abe41d484f25418c5c97ae3d'

# %% [markdown]
# ### Sending an API request

# %%
r = requests.get(url)
r.status_code
# Out:
# 200

# %% [markdown]
# ### Converting API JSON respond into python dict object

# %%
data = r.json()

# %%
data
# Out:
# {'adult': False,
#  'backdrop_path': '/8BTsTfln4jlQrLXUBquXJ0ASQy9.jpg',
#  'belongs_to_collection': {'id': 10,
#   'name': 'Star Wars Collection',
#   'poster_path': '/r8Ph5MYXL04Qzu4QBbq2KjqwtkQ.jpg',
#   'backdrop_path': '/d8duYyyC9J5T825Hg7grmaabfxQ.jpg'},
#  'budget': 245000000,
#  'genres': [{'id': 12, 'name': 'Adventure'},
#   {'id': 28, 'name': 'Action'},
#   {'id': 878, 'name': 'Science Fiction'},
#   {'id': 14, 'name': 'Fantasy'}],
#  'homepage': 'http://www.starwars.com/films/star-wars-episode-vii',
#  'id': 140607,
#  'imdb_id': 'tt2488496',
#  'original_language': 'en',
#  'original_title': 'Star Wars: The Force Awakens',
#  'overview': 'Thirty years after defeating the Galactic Empire, Han Solo and his allies face a new threat from the evil Kylo Ren and his army of Stormtroopers.',
#  'popularity': 54.208,
#  'poster_path': '/wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg',
#  'production_companies': [{'id': 1,
#    'logo_path': '/o86DbpburjxrqAzEDhXZcyE8pDb.png',
#    'name': 'Lucasfilm Ltd.',
#    'origin_country': 'US'},
#   {'id': 11461,
#    'logo_path': '/p9FoEt5shEKRWRKVIlvFaEmRnun.png',
#    'name': 'Bad Robot',
#    'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'US',
#    'name': 'United States of America'}],
#  'release_date': '2015-12-15',
#  'revenue': 2068223624,
#  'runtime': 136,
#  'spoken_languages': [{'english_name': 'English',
#    'iso_639_1': 'en',
#    'name': 'English'}],
#  'status': 'Released',
#  'tagline': 'Every generation has a story.',
#  'title': 'Star Wars: The Force Awakens',
#  'video': False,
#  'vote_average': 7.3,
#  'vote_count': 17949}

# %% [markdown]
# ##  Importing and Saving the Movies Dataset

# %%
movie_id = [0, 299534, 19995, 140607, 299536, 597, 135397,
            420818, 24428, 168259, 99861, 284054, 12445,
            181808, 330457, 351286, 109445, 321612, 260513]

# %%
basic_url = 'https://api.themoviedb.org/3/movie/{}?{}'

# %%
json_list = []
for movie in movie_id:
    url = basic_url.format(movie, api_key)
    r = requests.get(url)
    if r.status_code != 200:
        continue
    else:
        data = r.json()
        json_list.append(data) 
df = pd.DataFrame(json_list)
df.head()
# Out:
#    adult                     backdrop_path
# 0  False  /7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg  \
# 1  False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg
# 2  False  /8BTsTfln4jlQrLXUBquXJ0ASQy9.jpg
# 3  False  /mDfJG3LC3Dqb67AZ52x3Z0jU0uB.jpg
# 4  False  /rzdPqYx7Um4FUZeD8wpXqjAUcEm.jpg
#
#                                belongs_to_collection     budget
# 0  {'id': 86311, 'name': 'The Avengers Collection...  356000000  \
# 1  {'id': 87096, 'name': 'Avatar Collection', 'po...  237000000
# 2  {'id': 10, 'name': 'Star Wars Collection', 'po...  245000000
# 3  {'id': 86311, 'name': 'The Avengers Collection...  300000000
# 4                                               None  200000000
#
#                                               genres
# 0  [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...  \
# 1  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 3  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 4  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#
#                                             homepage      id    imdb_id
# 0     https://www.marvel.com/movies/avengers-endgame  299534  tt4154796  \
# 1               https://www.avatar.com/movies/avatar   19995  tt0499549
# 2  http://www.starwars.com/films/star-wars-episod...  140607  tt2488496
# 3  https://www.marvel.com/movies/avengers-infinit...  299536  tt4154756
# 4     https://www.paramountmovies.com/movies/titanic     597  tt0120338
#
#   original_language                original_title
# 0                en             Avengers: Endgame  \
# 1                en                        Avatar
# 2                en  Star Wars: The Force Awakens
# 3                en        Avengers: Infinity War
# 4                en                       Titanic
#
#                                             overview  popularity
# 0  After the devastating events of Avengers: Infi...     106.542  \
# 1  In the 22nd century, a paraplegic Marine is di...     203.551
# 2  Thirty years after defeating the Galactic Empi...      54.208
# 3  As the Avengers and their allies have continue...     213.639
# 4  101-year-old Rose DeWitt Bukater tells the sto...     114.682
#
#                         poster_path
# 0  /or06FN3Dka5tukK1e9sl16pB3iy.jpg  \
# 1  /jRXYjXNq0Cs2TcJjLkki24MLp7u.jpg
# 2  /wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg
# 3  /7WsyChQLEftFiDOVTGkv3hFpyyt.jpg
# 4  /9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg
#
#                                 production_companies
# 0  [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...  \
# 1  [{'id': 444, 'logo_path': None, 'name': 'Dune ...
# 2  [{'id': 1, 'logo_path': '/o86DbpburjxrqAzEDhXZ...
# 3  [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...
# 4  [{'id': 4, 'logo_path': '/gz66EfNoYPqHTYI4q9UE...
#
#                                 production_countries release_date     revenue
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   2019-04-24  2799439100  \
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   2009-12-15  2920357254
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...   2015-12-15  2068223624
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...   2018-04-25  2046239637
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...   1997-11-18  2187463944
#
#    runtime                                   spoken_languages    status
# 0      181  [{'english_name': 'English', 'iso_639_1': 'en'...  Released  \
# 1      162  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2      136  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3      149  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4      194  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                      tagline                         title
# 0                         Avenge the fallen.             Avengers: Endgame  \
# 1                Enter the world of Pandora.                        Avatar
# 2              Every generation has a story.  Star Wars: The Force Awakens
# 3      An entire universe. Once and for all.        Avengers: Infinity War
# 4  Nothing on Earth could come between them.                       Titanic
#
#    video  vote_average  vote_count
# 0  False         8.267       23047
# 1  False         7.569       28970
# 2  False         7.300       17949
# 3  False         8.263       26752
# 4  False         7.892       22787

# %% [markdown]
# ### Saving the movies dataset into the json format

# %%
df.to_json("tmdb_movies.json", orient = "records")

# %%
with open("tmdb_movies.json") as f:
    data = json.load(f)

# %%
df=pd.json_normalize(data,sep="_")
df.head()
# Out:
#    adult                     backdrop_path     budget
# 0  False  /7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg  356000000  \
# 1  False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  237000000
# 2  False  /8BTsTfln4jlQrLXUBquXJ0ASQy9.jpg  245000000
# 3  False  /mDfJG3LC3Dqb67AZ52x3Z0jU0uB.jpg  300000000
# 4  False  /rzdPqYx7Um4FUZeD8wpXqjAUcEm.jpg  200000000
#
#                                               genres
# 0  [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...  \
# 1  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 3  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 4  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#
#                                             homepage      id    imdb_id
# 0     https://www.marvel.com/movies/avengers-endgame  299534  tt4154796  \
# 1               https://www.avatar.com/movies/avatar   19995  tt0499549
# 2  http://www.starwars.com/films/star-wars-episod...  140607  tt2488496
# 3  https://www.marvel.com/movies/avengers-infinit...  299536  tt4154756
# 4     https://www.paramountmovies.com/movies/titanic     597  tt0120338
#
#   original_language                original_title
# 0                en             Avengers: Endgame  \
# 1                en                        Avatar
# 2                en  Star Wars: The Force Awakens
# 3                en        Avengers: Infinity War
# 4                en                       Titanic
#
#                                             overview  popularity
# 0  After the devastating events of Avengers: Infi...     106.542  \
# 1  In the 22nd century, a paraplegic Marine is di...     203.551
# 2  Thirty years after defeating the Galactic Empi...      54.208
# 3  As the Avengers and their allies have continue...     213.639
# 4  101-year-old Rose DeWitt Bukater tells the sto...     114.682
#
#                         poster_path
# 0  /or06FN3Dka5tukK1e9sl16pB3iy.jpg  \
# 1  /jRXYjXNq0Cs2TcJjLkki24MLp7u.jpg
# 2  /wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg
# 3  /7WsyChQLEftFiDOVTGkv3hFpyyt.jpg
# 4  /9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg
#
#                                 production_companies
# 0  [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...  \
# 1  [{'id': 444, 'logo_path': None, 'name': 'Dune ...
# 2  [{'id': 1, 'logo_path': '/o86DbpburjxrqAzEDhXZ...
# 3  [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...
# 4  [{'id': 4, 'logo_path': '/gz66EfNoYPqHTYI4q9UE...
#
#                                 production_countries release_date     revenue
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   2019-04-24  2799439100  \
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   2009-12-15  2920357254
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...   2015-12-15  2068223624
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...   2018-04-25  2046239637
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...   1997-11-18  2187463944
#
#    runtime                                   spoken_languages    status
# 0      181  [{'english_name': 'English', 'iso_639_1': 'en'...  Released  \
# 1      162  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2      136  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3      149  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4      194  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                      tagline                         title
# 0                         Avenge the fallen.             Avengers: Endgame  \
# 1                Enter the world of Pandora.                        Avatar
# 2              Every generation has a story.  Star Wars: The Force Awakens
# 3      An entire universe. Once and for all.        Avengers: Infinity War
# 4  Nothing on Earth could come between them.                       Titanic
#
#    video  vote_average  vote_count  belongs_to_collection_id
# 0  False         8.267       23047                   86311.0  \
# 1  False         7.569       28970                   87096.0
# 2  False         7.300       17949                      10.0
# 3  False         8.263       26752                   86311.0
# 4  False         7.892       22787                       NaN
#
#   belongs_to_collection_name belongs_to_collection_poster_path
# 0    The Avengers Collection  /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg  \
# 1          Avatar Collection  /uO2yU3QiGHvVp0L5e5IatTVRkYk.jpg
# 2       Star Wars Collection  /r8Ph5MYXL04Qzu4QBbq2KjqwtkQ.jpg
# 3    The Avengers Collection  /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg
# 4                        NaN                               NaN
#
#   belongs_to_collection_backdrop_path  belongs_to_collection
# 0    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg                    NaN
# 1    /iaEsDbQPE45hQU2EGiNjXD2KWuF.jpg                    NaN
# 2    /d8duYyyC9J5T825Hg7grmaabfxQ.jpg                    NaN
# 3    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg                    NaN
# 4                                 NaN                    NaN

# %%
pd.json_normalize(data, record_path="genres", meta="title")
# Out:
#        id             name                 title
# 0      12        Adventure     Avengers: Endgame
# 1     878  Science Fiction     Avengers: Endgame
# 2      28           Action     Avengers: Endgame
# 3      28           Action                Avatar
# 4      12        Adventure                Avatar
# ..    ...              ...                   ...
# 56  10749          Romance  Beauty and the Beast
# 57     28           Action         Incredibles 2
# 58     12        Adventure         Incredibles 2
# 59     16        Animation         Incredibles 2
# 60  10751           Family         Incredibles 2
#
# [61 rows x 3 columns]

# %% [markdown]
# ## What is in the theatre now?

# %%
discover_api = "https://api.themoviedb.org/3/discover/movie?"

# %%
query = "&primary_release_date.gte=2023-03-01&primary_release_date.lte=2023-04-20"
#query = "&primary_release_date.gte=2020-01-01&primary_release_date.lte=2020-02-29&page=2"

# %%
url = discover_api+api_key+query
url
# Out:
# 'https://api.themoviedb.org/3/discover/movie?api_key=1c571334abe41d484f25418c5c97ae3d&primary_release_date.gte=2023-03-01&primary_release_date.lte=2023-04-20'

# %%
res = requests.get(url)

# %%
data=res.json()

# %%
data.keys()
# Out:
# dict_keys(['page', 'results', 'total_pages', 'total_results'])

# %%
len(data["results"])
# Out:
# 20

# %%
len(data["results"][0])
# Out:
# 14

# %%
pd.json_normalize(data=data,record_path="results").head()
# Out:
#    adult                     backdrop_path                genre_ids      id
# 0  False  /iJQIbOPm81fPEGKt5BPuZmfnA54.jpg  [16, 12, 10751, 14, 35]  502356  \
# 1  False  /nDxJJyA5giRhXx96q1sWbOUjMBI.jpg             [28, 35, 14]  594767
# 2  False  /xwA90BwZXTh8ke3CVsQlj8EOkFr.jpg  [28, 12, 36, 18, 10752]  948713
# 3  False  /5i6SjyDbDWqyun8klUuCxrlFbyw.jpg                 [18, 28]  677179
# 4  False  /bT3IpP7OopgiVuy6HCPOWLuaFAd.jpg           [35, 9648, 28]  638974
#
#   original_language                          original_title
# 0                en             The Super Mario Bros. Movie  \
# 1                en                Shazam! Fury of the Gods
# 2                en  The Last Kingdom: Seven Kings Must Die
# 3                en                               Creed III
# 4                en                        Murder Mystery 2
#
#                                             overview  popularity
# 0  While working underground to fix a water main,...    6572.614  \
# 1  Billy Batson and his foster siblings, who tran...    4274.232
# 2  In the wake of King Edward's death, Uhtred of ...    3119.049
# 3  After dominating the boxing world, Adonis Cree...    2856.222
# 4  After starting their own detective agency, Nic...    1879.655
#
#                         poster_path release_date
# 0  /qNBAXBIQlnOThrVvA6mA2B5ggV6.jpg   2023-04-05  \
# 1  /2VK4d3mqqTc7LVZLnLPeRiPaJ71.jpg   2023-03-15
# 2  /7yyFEsuaLGTPul5UkHc5BhXnQ0k.jpg   2023-04-14
# 3  /cvsXj3I9Q2iyyIo95AecSd1tad7.jpg   2023-03-01
# 4  /s1VzVhXlqsevi8zeCMG9A16nEUf.jpg   2023-03-28
#
#                                     title  video  vote_average  vote_count
# 0             The Super Mario Bros. Movie  False           7.5        1456
# 1                Shazam! Fury of the Gods  False           6.9        1231
# 2  The Last Kingdom: Seven Kings Must Die  False           7.4         232
# 3                               Creed III  False           7.3        1192
# 4                        Murder Mystery 2  False           6.5         864

# %%
pd.DataFrame(data["results"]).head()
# Out:
#    adult                     backdrop_path                genre_ids      id
# 0  False  /iJQIbOPm81fPEGKt5BPuZmfnA54.jpg  [16, 12, 10751, 14, 35]  502356  \
# 1  False  /nDxJJyA5giRhXx96q1sWbOUjMBI.jpg             [28, 35, 14]  594767
# 2  False  /xwA90BwZXTh8ke3CVsQlj8EOkFr.jpg  [28, 12, 36, 18, 10752]  948713
# 3  False  /5i6SjyDbDWqyun8klUuCxrlFbyw.jpg                 [18, 28]  677179
# 4  False  /bT3IpP7OopgiVuy6HCPOWLuaFAd.jpg           [35, 9648, 28]  638974
#
#   original_language                          original_title
# 0                en             The Super Mario Bros. Movie  \
# 1                en                Shazam! Fury of the Gods
# 2                en  The Last Kingdom: Seven Kings Must Die
# 3                en                               Creed III
# 4                en                        Murder Mystery 2
#
#                                             overview  popularity
# 0  While working underground to fix a water main,...    6572.614  \
# 1  Billy Batson and his foster siblings, who tran...    4274.232
# 2  In the wake of King Edward's death, Uhtred of ...    3119.049
# 3  After dominating the boxing world, Adonis Cree...    2856.222
# 4  After starting their own detective agency, Nic...    1879.655
#
#                         poster_path release_date
# 0  /qNBAXBIQlnOThrVvA6mA2B5ggV6.jpg   2023-04-05  \
# 1  /2VK4d3mqqTc7LVZLnLPeRiPaJ71.jpg   2023-03-15
# 2  /7yyFEsuaLGTPul5UkHc5BhXnQ0k.jpg   2023-04-14
# 3  /cvsXj3I9Q2iyyIo95AecSd1tad7.jpg   2023-03-01
# 4  /s1VzVhXlqsevi8zeCMG9A16nEUf.jpg   2023-03-28
#
#                                     title  video  vote_average  vote_count
# 0             The Super Mario Bros. Movie  False           7.5        1456
# 1                Shazam! Fury of the Gods  False           6.9        1231
# 2  The Last Kingdom: Seven Kings Must Die  False           7.4         232
# 3                               Creed III  False           7.3        1192
# 4                        Murder Mystery 2  False           6.5         864

# %% [markdown]
# # Saving and Importing the Movies Dataset

# %%
df.to_csv("tmdb_movies_raw.csv", index = False)

# %%
df = pd.read_csv("tmdb_movies_raw.csv")

# %%
df.head()
# Out:
#    adult                     backdrop_path     budget
# 0  False  /7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg  356000000  \
# 1  False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  237000000
# 2  False  /8BTsTfln4jlQrLXUBquXJ0ASQy9.jpg  245000000
# 3  False  /mDfJG3LC3Dqb67AZ52x3Z0jU0uB.jpg  300000000
# 4  False  /rzdPqYx7Um4FUZeD8wpXqjAUcEm.jpg  200000000
#
#                                               genres
# 0  [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...  \
# 1  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 3  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 4  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#
#                                             homepage      id    imdb_id
# 0     https://www.marvel.com/movies/avengers-endgame  299534  tt4154796  \
# 1               https://www.avatar.com/movies/avatar   19995  tt0499549
# 2  http://www.starwars.com/films/star-wars-episod...  140607  tt2488496
# 3  https://www.marvel.com/movies/avengers-infinit...  299536  tt4154756
# 4     https://www.paramountmovies.com/movies/titanic     597  tt0120338
#
#   original_language                original_title
# 0                en             Avengers: Endgame  \
# 1                en                        Avatar
# 2                en  Star Wars: The Force Awakens
# 3                en        Avengers: Infinity War
# 4                en                       Titanic
#
#                                             overview  popularity
# 0  After the devastating events of Avengers: Infi...     106.542  \
# 1  In the 22nd century, a paraplegic Marine is di...     203.551
# 2  Thirty years after defeating the Galactic Empi...      54.208
# 3  As the Avengers and their allies have continue...     213.639
# 4  101-year-old Rose DeWitt Bukater tells the sto...     114.682
#
#                         poster_path
# 0  /or06FN3Dka5tukK1e9sl16pB3iy.jpg  \
# 1  /jRXYjXNq0Cs2TcJjLkki24MLp7u.jpg
# 2  /wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg
# 3  /7WsyChQLEftFiDOVTGkv3hFpyyt.jpg
# 4  /9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg
#
#                                 production_companies
# 0  [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...  \
# 1  [{'id': 444, 'logo_path': None, 'name': 'Dune ...
# 2  [{'id': 1, 'logo_path': '/o86DbpburjxrqAzEDhXZ...
# 3  [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...
# 4  [{'id': 4, 'logo_path': '/gz66EfNoYPqHTYI4q9UE...
#
#                                 production_countries release_date     revenue
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   2019-04-24  2799439100  \
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   2009-12-15  2920357254
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...   2015-12-15  2068223624
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...   2018-04-25  2046239637
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...   1997-11-18  2187463944
#
#    runtime                                   spoken_languages    status
# 0      181  [{'english_name': 'English', 'iso_639_1': 'en'...  Released  \
# 1      162  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2      136  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3      149  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4      194  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                      tagline                         title
# 0                         Avenge the fallen.             Avengers: Endgame  \
# 1                Enter the world of Pandora.                        Avatar
# 2              Every generation has a story.  Star Wars: The Force Awakens
# 3      An entire universe. Once and for all.        Avengers: Infinity War
# 4  Nothing on Earth could come between them.                       Titanic
#
#    video  vote_average  vote_count  belongs_to_collection_id
# 0  False         8.267       23047                   86311.0  \
# 1  False         7.569       28970                   87096.0
# 2  False         7.300       17949                      10.0
# 3  False         8.263       26752                   86311.0
# 4  False         7.892       22787                       NaN
#
#   belongs_to_collection_name belongs_to_collection_poster_path
# 0    The Avengers Collection  /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg  \
# 1          Avatar Collection  /uO2yU3QiGHvVp0L5e5IatTVRkYk.jpg
# 2       Star Wars Collection  /r8Ph5MYXL04Qzu4QBbq2KjqwtkQ.jpg
# 3    The Avengers Collection  /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg
# 4                        NaN                               NaN
#
#   belongs_to_collection_backdrop_path  belongs_to_collection
# 0    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg                    NaN
# 1    /iaEsDbQPE45hQU2EGiNjXD2KWuF.jpg                    NaN
# 2    /d8duYyyC9J5T825Hg7grmaabfxQ.jpg                    NaN
# 3    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg                    NaN
# 4                                 NaN                    NaN
